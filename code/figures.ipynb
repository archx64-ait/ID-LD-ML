# %%
import pandas as pd

pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
df = pd.read_parquet('preprocessed.parquet')

# %%
df.head(20)
# Out:
#     Avg Packet Size  Packet Length Mean  Bwd Packet Length Std  \
# 0          9.000000            6.000000               0.000000
# 1          9.000000            6.000000               0.000000
# 2          9.000000            6.000000               0.000000
# 3          9.000000            6.000000               0.000000
# 4         81.636360           74.833336             119.511505
# 5        286.153839          265.714294             884.500610
# 6        412.133331          386.375000             782.347229
# 7        512.000000          469.333344             814.063904
# 8          9.000000            6.000000               0.000000
# 9        414.666656          388.750000             785.445618
# 10       380.153839          366.074066             817.308960
# 11        74.000000           67.833336             102.768349
# 12       274.769226          255.142853             849.282227
# 13       502.545441          460.666656             802.516846
# ...

# %%
import dataframe_image as dfi

df_styled = df.head(40).style.background_gradient(cmap='icefire')

dfi.export(df_styled, 'my_df.png')
